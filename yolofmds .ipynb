# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (0.5.4)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.1-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Using cached keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from tensorflow) (1.26.4)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting pillow (from tensorboard~=2.20.0->tensorflow)
#   Downloading pillow-12.0.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.18.0-cp310-cp310-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\administrator\anaconda3\envs\py310\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
#    ---------------------------------------- 0.0/331.7 MB ? eta -:--:--
#    ---------------------------------------- 2.1/331.7 MB 13.0 MB/s eta 0:00:26
#    ---------------------------------------- 3.7/331.7 MB 10.4 MB/s eta 0:00:32
#     --------------------------------------- 6.6/331.7 MB 10.6 MB/s eta 0:00:31
#    - -------------------------------------- 8.9/331.7 MB 10.9 MB/s eta 0:00:30
#    - -------------------------------------- 11.8/331.7 MB 11.0 MB/s eta 0:00:30
#    - -------------------------------------- 14.2/331.7 MB 11.3 MB/s eta 0:00:29
#    - -------------------------------------- 16.5/331.7 MB 11.2 MB/s eta 0:00:29
#    -- ------------------------------------- 18.4/331.7 MB 11.0 MB/s eta 0:00:29
#    -- ------------------------------------- 20.7/331.7 MB 10.7 MB/s eta 0:00:29
#    -- ------------------------------------- 23.1/331.7 MB 10.8 MB/s eta 0:00:29
#    --- ------------------------------------ 25.4/331.7 MB 10.8 MB/s eta 0:00:29
#    --- ------------------------------------ 27.8/331.7 MB 10.9 MB/s eta 0:00:28
#    --- ------------------------------------ 30.1/331.7 MB 10.9 MB/s eta 0:00:28
#    --- ------------------------------------ 32.8/331.7 MB 10.9 MB/s eta 0:00:28
#    ---- ----------------------------------- 35.4/331.7 MB 11.0 MB/s eta 0:00:27
#    ---- ----------------------------------- 37.7/331.7 MB 11.1 MB/s eta 0:00:27
#    ---- ----------------------------------- 40.1/331.7 MB 11.0 MB/s eta 0:00:27
#    ----- ---------------------------------- 42.5/331.7 MB 11.0 MB/s eta 0:00:27
#    ----- ---------------------------------- 44.8/331.7 MB 11.0 MB/s eta 0:00:27
#    ----- ---------------------------------- 47.2/331.7 MB 11.0 MB/s eta 0:00:26
#    ------ --------------------------------- 49.8/331.7 MB 11.0 MB/s eta 0:00:26
#    ------ --------------------------------- 52.2/331.7 MB 11.1 MB/s eta 0:00:26
#    ------ --------------------------------- 54.5/331.7 MB 11.1 MB/s eta 0:00:25
#    ------ --------------------------------- 57.1/331.7 MB 11.1 MB/s eta 0:00:25
#    ------- -------------------------------- 59.8/331.7 MB 11.1 MB/s eta 0:00:25
#    ------- -------------------------------- 61.9/331.7 MB 11.1 MB/s eta 0:00:25
#    ------- -------------------------------- 64.5/331.7 MB 11.1 MB/s eta 0:00:25
#    -------- ------------------------------- 67.1/331.7 MB 11.1 MB/s eta 0:00:24
#    -------- ------------------------------- 69.5/331.7 MB 11.2 MB/s eta 0:00:24
#    -------- ------------------------------- 71.8/331.7 MB 11.2 MB/s eta 0:00:24
#    -------- ------------------------------- 74.4/331.7 MB 11.2 MB/s eta 0:00:24
#    --------- ------------------------------ 76.8/331.7 MB 11.2 MB/s eta 0:00:23
#    --------- ------------------------------ 79.4/331.7 MB 11.2 MB/s eta 0:00:23
#    --------- ------------------------------ 82.1/331.7 MB 11.2 MB/s eta 0:00:23
#    ---------- ----------------------------- 84.7/331.7 MB 11.3 MB/s eta 0:00:22
#    ---------- ----------------------------- 87.0/331.7 MB 11.2 MB/s eta 0:00:22
#    ---------- ----------------------------- 89.4/331.7 MB 11.3 MB/s eta 0:00:22
#    ----------- ---------------------------- 92.0/331.7 MB 11.3 MB/s eta 0:00:22
#    ----------- ---------------------------- 94.6/331.7 MB 11.3 MB/s eta 0:00:21
#    ----------- ---------------------------- 97.3/331.7 MB 11.3 MB/s eta 0:00:21
#    ------------ --------------------------- 99.9/331.7 MB 11.3 MB/s eta 0:00:21
#    ------------ -------------------------- 102.2/331.7 MB 11.3 MB/s eta 0:00:21
#    ------------ -------------------------- 105.1/331.7 MB 11.3 MB/s eta 0:00:20
#    ------------ -------------------------- 108.0/331.7 MB 11.4 MB/s eta 0:00:20
#    ------------ -------------------------- 110.4/331.7 MB 11.4 MB/s eta 0:00:20
#    ------------- ------------------------- 113.0/331.7 MB 11.4 MB/s eta 0:00:20
#    ------------- ------------------------- 115.6/331.7 MB 11.4 MB/s eta 0:00:19
#    ------------- ------------------------- 118.0/331.7 MB 11.4 MB/s eta 0:00:19
#    -------------- ------------------------ 120.3/331.7 MB 11.4 MB/s eta 0:00:19
#    -------------- ------------------------ 122.4/331.7 MB 11.3 MB/s eta 0:00:19
#    -------------- ------------------------ 124.8/331.7 MB 11.3 MB/s eta 0:00:19
#    -------------- ------------------------ 126.9/331.7 MB 11.3 MB/s eta 0:00:19
#    --------------- ----------------------- 129.0/331.7 MB 11.2 MB/s eta 0:00:19
#    --------------- ----------------------- 131.1/331.7 MB 11.2 MB/s eta 0:00:18
#    --------------- ----------------------- 133.4/331.7 MB 11.2 MB/s eta 0:00:18
#    --------------- ----------------------- 135.5/331.7 MB 11.2 MB/s eta 0:00:18
#    ---------------- ---------------------- 137.9/331.7 MB 11.1 MB/s eta 0:00:18
#    ---------------- ---------------------- 139.7/331.7 MB 11.1 MB/s eta 0:00:18
#    ---------------- ---------------------- 142.1/331.7 MB 11.1 MB/s eta 0:00:18
#    ---------------- ---------------------- 144.2/331.7 MB 11.1 MB/s eta 0:00:17
#    ----------------- --------------------- 146.5/331.7 MB 11.1 MB/s eta 0:00:17
#    ----------------- --------------------- 148.9/331.7 MB 11.1 MB/s eta 0:00:17
#    ----------------- --------------------- 151.0/331.7 MB 11.1 MB/s eta 0:00:17
#    ------------------ -------------------- 153.4/331.7 MB 11.0 MB/s eta 0:00:17
#    ------------------ -------------------- 155.2/331.7 MB 11.0 MB/s eta 0:00:17
#    ------------------ -------------------- 157.0/331.7 MB 11.0 MB/s eta 0:00:16
#    ------------------ -------------------- 159.4/331.7 MB 11.0 MB/s eta 0:00:16
#    ------------------- ------------------- 161.7/331.7 MB 11.0 MB/s eta 0:00:16
#    ------------------- ------------------- 164.1/331.7 MB 11.0 MB/s eta 0:00:16
#    ------------------- ------------------- 166.2/331.7 MB 11.0 MB/s eta 0:00:16
#    ------------------- ------------------- 168.0/331.7 MB 10.9 MB/s eta 0:00:15
#    -------------------- ------------------ 170.7/331.7 MB 10.9 MB/s eta 0:00:15
#    -------------------- ------------------ 172.8/331.7 MB 10.9 MB/s eta 0:00:15
#    -------------------- ------------------ 174.9/331.7 MB 10.9 MB/s eta 0:00:15
#    -------------------- ------------------ 176.9/331.7 MB 10.9 MB/s eta 0:00:15
#    --------------------- ----------------- 179.3/331.7 MB 10.9 MB/s eta 0:00:14
#    --------------------- ----------------- 181.4/331.7 MB 10.9 MB/s eta 0:00:14
#    --------------------- ----------------- 183.5/331.7 MB 10.9 MB/s eta 0:00:14
#    --------------------- ----------------- 185.6/331.7 MB 10.9 MB/s eta 0:00:14
#    ---------------------- ---------------- 188.0/331.7 MB 10.9 MB/s eta 0:00:14
#    ---------------------- ---------------- 190.3/331.7 MB 10.9 MB/s eta 0:00:14
#    ---------------------- ---------------- 192.9/331.7 MB 10.9 MB/s eta 0:00:13
#    ---------------------- ---------------- 195.3/331.7 MB 10.9 MB/s eta 0:00:13
#    ----------------------- --------------- 197.7/331.7 MB 10.9 MB/s eta 0:00:13
#    ----------------------- --------------- 200.0/331.7 MB 10.9 MB/s eta 0:00:13
#    ----------------------- --------------- 202.6/331.7 MB 10.9 MB/s eta 0:00:12
#    ------------------------ -------------- 205.0/331.7 MB 10.9 MB/s eta 0:00:12
#    ------------------------ -------------- 207.4/331.7 MB 10.9 MB/s eta 0:00:12
#    ------------------------ -------------- 209.7/331.7 MB 10.9 MB/s eta 0:00:12
#    ------------------------ -------------- 212.1/331.7 MB 10.9 MB/s eta 0:00:11
#    ------------------------- ------------- 214.2/331.7 MB 10.9 MB/s eta 0:00:11
#    ------------------------- ------------- 216.5/331.7 MB 10.9 MB/s eta 0:00:11
#    ------------------------- ------------- 218.9/331.7 MB 10.9 MB/s eta 0:00:11
#    ------------------------- ------------- 221.0/331.7 MB 10.9 MB/s eta 0:00:11
#    -------------------------- ------------ 223.6/331.7 MB 10.9 MB/s eta 0:00:10
#    -------------------------- ------------ 226.2/331.7 MB 10.9 MB/s eta 0:00:10
#    -------------------------- ------------ 228.6/331.7 MB 10.9 MB/s eta 0:00:10
#    --------------------------- ----------- 230.9/331.7 MB 10.9 MB/s eta 0:00:10
#    --------------------------- ----------- 233.0/331.7 MB 10.9 MB/s eta 0:00:10
#    --------------------------- ----------- 235.7/331.7 MB 10.9 MB/s eta 0:00:09
#    ---------------------------- ---------- 238.3/331.7 MB 10.9 MB/s eta 0:00:09
#    ---------------------------- ---------- 240.9/331.7 MB 10.9 MB/s eta 0:00:09
#    ---------------------------- ---------- 243.3/331.7 MB 10.9 MB/s eta 0:00:09
#    ---------------------------- ---------- 245.6/331.7 MB 10.9 MB/s eta 0:00:08
#    ----------------------------- --------- 247.7/331.7 MB 10.9 MB/s eta 0:00:08
#    ----------------------------- --------- 250.1/331.7 MB 10.9 MB/s eta 0:00:08
#    ----------------------------- --------- 252.7/331.7 MB 10.9 MB/s eta 0:00:08
#    ----------------------------- --------- 255.1/331.7 MB 10.9 MB/s eta 0:00:08
#    ------------------------------ -------- 257.7/331.7 MB 10.9 MB/s eta 0:00:07
#    ------------------------------ -------- 259.5/331.7 MB 10.9 MB/s eta 0:00:07
#    ------------------------------ -------- 261.9/331.7 MB 10.9 MB/s eta 0:00:07
#    ------------------------------- ------- 264.2/331.7 MB 10.9 MB/s eta 0:00:07
#    ------------------------------- ------- 266.6/331.7 MB 10.9 MB/s eta 0:00:06
#    ------------------------------- ------- 268.7/331.7 MB 10.9 MB/s eta 0:00:06
#    ------------------------------- ------- 271.3/331.7 MB 10.9 MB/s eta 0:00:06
#    -------------------------------- ------ 273.7/331.7 MB 10.9 MB/s eta 0:00:06
#    -------------------------------- ------ 276.0/331.7 MB 10.9 MB/s eta 0:00:06
#    -------------------------------- ------ 278.7/331.7 MB 10.9 MB/s eta 0:00:05
#    --------------------------------- ----- 281.3/331.7 MB 10.9 MB/s eta 0:00:05
#    --------------------------------- ----- 283.6/331.7 MB 10.9 MB/s eta 0:00:05
#    --------------------------------- ----- 286.3/331.7 MB 10.9 MB/s eta 0:00:05
#    --------------------------------- ----- 288.6/331.7 MB 10.9 MB/s eta 0:00:04
#    ---------------------------------- ---- 291.2/331.7 MB 10.9 MB/s eta 0:00:04
#    ---------------------------------- ---- 293.6/331.7 MB 10.9 MB/s eta 0:00:04
#    ---------------------------------- ---- 295.7/331.7 MB 10.9 MB/s eta 0:00:04
#    ----------------------------------- --- 298.1/331.7 MB 10.9 MB/s eta 0:00:04
#    ----------------------------------- --- 299.9/331.7 MB 10.9 MB/s eta 0:00:03
#    ----------------------------------- --- 301.7/331.7 MB 10.9 MB/s eta 0:00:03
#    ----------------------------------- --- 303.3/331.7 MB 10.9 MB/s eta 0:00:03
#    ----------------------------------- --- 305.1/331.7 MB 10.8 MB/s eta 0:00:03
#    ------------------------------------ -- 307.8/331.7 MB 10.8 MB/s eta 0:00:03
#    ------------------------------------ -- 310.4/331.7 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------ -- 313.0/331.7 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 315.6/331.7 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 317.7/331.7 MB 10.8 MB/s eta 0:00:02
#    ------------------------------------- - 320.1/331.7 MB 10.9 MB/s eta 0:00:02
#    ------------------------------------- - 322.4/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  324.5/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  326.9/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  329.0/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.4/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 10.8 MB/s eta 0:00:01
#    --------------------------------------  331.6/331.7 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 331.7/331.7 MB 10.4 MB/s  0:00:31
# Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    --------------- ------------------------ 1.8/4.7 MB 9.1 MB/s eta 0:00:01
#    --------------------------------- ------ 3.9/4.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 9.2 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ----------------------------- ---------- 2.1/2.9 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 10.4 MB/s  0:00:00
# Using cached keras-3.12.0-py3-none-any.whl (1.5 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl (436 kB)
# Using cached termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-2.0.1-cp310-cp310-win_amd64.whl (60 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.18.0-cp310-cp310-win_amd64.whl (302 kB)
# Downloading pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------- -------------- 4.5/7.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 11.3 MB/s  0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, pillow, optree, opt_einsum, ml_dtypes, mdurl, markdown, h5py, grpcio, google_pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow
#
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    - --------------------------------------  1/25 [libclang]
#    ---- -----------------------------------  3/25 [wrapt]
#    ------ ---------------------------------  4/25 [werkzeug]
#    ------ ---------------------------------  4/25 [werkzeug]
#    ------ ---------------------------------  4/25 [werkzeug]
#    --------- ------------------------------  6/25 [tensorboard-data-server]
#    ----------- ----------------------------  7/25 [protobuf]
#    ----------- ----------------------------  7/25 [protobuf]
#    ----------- ----------------------------  7/25 [protobuf]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    ------------ ---------------------------  8/25 [pillow]
#    -------------- -------------------------  9/25 [optree]
#    ---------------- ----------------------- 10/25 [opt_einsum]
#    ---------------- ----------------------- 10/25 [opt_einsum]
#    ----------------- ---------------------- 11/25 [ml_dtypes]
#    -------------------- ------------------- 13/25 [markdown]
#    ---------------------- ----------------- 14/25 [h5py]
#    ---------------------- ----------------- 14/25 [h5py]
#    ---------------------- ----------------- 14/25 [h5py]
#    ---------------------- ----------------- 14/25 [h5py]
#    ------------------------ --------------- 15/25 [grpcio]
#    ------------------------ --------------- 15/25 [grpcio]
#    ------------------------ --------------- 15/25 [grpcio]
#    ------------------------- -------------- 16/25 [google_pasta]
#    --------------------------- ------------ 17/25 [gast]
#    ------------------------------ --------- 19/25 [absl-py]
#    ------------------------------ --------- 19/25 [absl-py]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    -------------------------------- ------- 20/25 [tensorboard]
#    --------------------------------- ------ 21/25 [markdown-it-py]
#    --------------------------------- ------ 21/25 [markdown-it-py]
#    ----------------------------------- ---- 22/25 [rich]
#    ----------------------------------- ---- 22/25 [rich]
#    ----------------------------------- ---- 22/25 [rich]
#    ----------------------------------- ---- 22/25 [rich]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    ------------------------------------ --- 23/25 [keras]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    -------------------------------------- - 24/25 [tensorflow]
#    ---------------------------------------- 25/25 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.9.23 gast-0.6.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.12.0 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.18.0 pillow-12.0.0 protobuf-6.33.1 rich-14.2.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 werkzeug-3.1.3 wrapt-2.0.1

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.12.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Install missing package
# !pip install imutils

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import os

INIT_LR = 1e-4
EPOCHS = 20
BS = 32

DIRECTORY = r"C:\Users\Administrator\Desktop\krish_P_Detection_system\p1\data"
CATEGORIES = ["with_mask", "without_mask"]

print("[INFO] loading images...")
data = []
labels = []

for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        image = load_img(img_path, target_size=(224, 224))
        image = img_to_array(image)
        image = preprocess_input(image)
        data.append(image)
        labels.append(category)

# one-hot encode labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

data = np.array(data, dtype="float32")
labels = np.array(labels)

trainX, testX, trainY, testY = train_test_split(
    data, labels, test_size=0.20, stratify=labels, random_state=42
)

aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)

baseModel = MobileNetV2(weights="imagenet", include_top=False,
                        input_tensor=Input(shape=(224, 224, 3)))

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten()(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:
    layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(learning_rate=INIT_LR)
model.compile(loss="binary_crossentropy", optimizer=opt,
              metrics=["accuracy"])

print("[INFO] training head...")
H = model.fit(
    aug.flow(trainX, trainY, batch_size=BS),
    steps_per_epoch=len(trainX) // BS,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BS,
    epochs=EPOCHS)

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)

print(classification_report(testY.argmax(axis=1), predIdxs,
                            target_names=lb.classes_))

print("[INFO] saving mask detector model...")
model.save("mask_detector.h5")

# Plot training graph
plt.style.use("ggplot")
plt.figure()
plt.plot(H.history["loss"], label="train_loss")
plt.plot(H.history["val_loss"], label="val_loss")
plt.plot(H.history["accuracy"], label="train_acc")
plt.plot(H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")
plt.show()
# Out:
# [INFO] loading images...
# C:\Users\Administrator\anaconda3\envs\py310\lib\site-packages\PIL\Image.py:1039: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   del new_im.info["transparency"]
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12004\3937558546.py:63: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   baseModel = MobileNetV2(weights="imagenet", include_top=False,
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.9118 - loss: 0.2715 - val_accuracy: 0.9749 - val_loss: 0.0919
# Epoch 2/20
# C:\Users\Administrator\anaconda3\envs\py310\lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 28s 149ms/step - accuracy: 1.0000 - loss: 0.1151 - val_accuracy: 0.9749 - val_loss: 0.0918
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 231s 1s/step - accuracy: 0.9780 - loss: 0.0890 - val_accuracy: 0.9782 - val_loss: 0.0572
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.9062 - loss: 0.1716 - val_accuracy: 0.9782 - val_loss: 0.0571
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.9814 - loss: 0.0648 - val_accuracy: 0.9815 - val_loss: 0.0479
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 39s 204ms/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 0.9815 - val_loss: 0.0479
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 339s 2s/step - accuracy: 0.9854 - loss: 0.0536 - val_accuracy: 0.9835 - val_loss: 0.0440
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 27s 144ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.9828 - val_loss: 0.0438
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 310s 2s/step - accuracy: 0.9875 - loss: 0.0435 - val_accuracy: 0.9835 - val_loss: 0.0437
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 41s 209ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9835 - val_loss: 0.0441
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 375s 2s/step - accuracy: 0.9862 - loss: 0.0472 - val_accuracy: 0.9848 - val_loss: 0.0393
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 43s 222ms/step - accuracy: 0.9688 - loss: 0.0986 - val_accuracy: 0.9848 - val_loss: 0.0393
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9879 - loss: 0.0398 - val_accuracy: 0.9848 - val_loss: 0.0376
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 42s 220ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9841 - val_loss: 0.0375
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.9867 - loss: 0.0396 - val_accuracy: 0.9868 - val_loss: 0.0364
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.9868 - val_loss: 0.0365
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 309s 2s/step - accuracy: 0.9895 - loss: 0.0362 - val_accuracy: 0.9868 - val_loss: 0.0345
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 42s 221ms/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 0.9868 - val_loss: 0.0345
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 290s 2s/step - accuracy: 0.9895 - loss: 0.0324 - val_accuracy: 0.9868 - val_loss: 0.0340
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 39s 208ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9868 - val_loss: 0.0340
# [INFO] evaluating network...
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 46s 872ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#               precision    recall  f1-score   support
#
#    with_mask       0.99      0.99      0.99       745
# without_mask       0.99      0.99      0.99       766
#
#     accuracy                           0.99      1511
#    macro avg       0.99      0.99      0.99      1511
# weighted avg       0.99      0.99      0.99      1511
#
# [INFO] saving mask detector model...

# %%
# import the necessary packages
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from imutils.video import VideoStream
import numpy as np
import imutils
import time
import cv2
import os


def detect_and_predict_mask(frame, faceNet, maskNet):

    (h, w) = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 1.0, (224, 224),
                                 (104.0, 177.0, 123.0))

    faceNet.setInput(blob)
    detections = faceNet.forward()

    faces = []
    locs = []
    preds = []

    for i in range(0, detections.shape[2]):
        confidence = detections[0, 0, i, 2]

        if confidence > 0.5:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            (startX, startY) = (max(0, startX), max(0, startY))
            (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

            face = frame[startY:endY, startX:endX]

            if face.size == 0:
                continue  # skip bad face crop

            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)

            faces.append(face)
            locs.append((startX, startY, endX, endY))

    if len(faces) > 0:
        faces = np.array(faces, dtype="float32")
        preds = maskNet.predict(faces, batch_size=32)

    return (locs, preds)


# LOAD MODELS
prototxtPath = r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\deploy.prototxt"
weightsPath = r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\res10_300x300_ssd_iter_140000.caffemodel"

faceNet = cv2.dnn.readNet(prototxtPath, weightsPath)
maskNet = load_model(r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\mask_detector.h5")


# START VIDEO STREAM
print("[INFO] starting video stream...")
vs = VideoStream(src=0).start()   
time.sleep(2.0)

while True:

    frame = vs.read()

    if frame is None:
        print("[WARNING] Frame is None — retrying...")
        continue

    try:
        frame = imutils.resize(frame, width=850)
    except:
        print("[ERROR] Could not resize frame")
        continue

    (locs, preds) = detect_and_predict_mask(frame, faceNet, maskNet)

    for (box, pred) in zip(locs, preds):
        (startX, startY, endX, endY) = box
        (mask, withoutMask) = pred

        label = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)
        label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

        cv2.putText(frame, label, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 3)
        cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1) & 0xFF

    if key == ord("q"):
        break

cv2.destroyAllWindows()
vs.stop()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [INFO] starting video stream...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %% [markdown]
# Specific image

# %%
#specific image vala


# # import the necessary packages
# from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
# from tensorflow.keras.preprocessing.image import img_to_array
# from tensorflow.keras.models import load_model
# import numpy as np
# import cv2
# import os

# def detect_and_predict_mask(image, faceNet, maskNet):
#     (h, w) = image.shape[:2]
#     blob = cv2.dnn.blobFromImage(image, 1.0, (224, 224),
#                                  (104.0, 177.0, 123.0))

#     faceNet.setInput(blob)
#     detections = faceNet.forward()

#     faces = []
#     locs = []
#     preds = []

#     for i in range(0, detections.shape[2]):
#         confidence = detections[0, 0, i, 2]

#         if confidence > 0.5:
#             box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
#             (startX, startY, endX, endY) = box.astype("int")

#             (startX, startY) = (max(0, startX), max(0, startY))
#             (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

#             face = image[startY:endY, startX:endX]
#             if face.size == 0:
#                 continue

#             face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
#             face = cv2.resize(face, (224, 224))
#             face = img_to_array(face)
#             face = preprocess_input(face)

#             faces.append(face)
#             locs.append((startX, startY, endX, endY))

#     if len(faces) > 0:
#         faces = np.array(faces, dtype="float32")
#         preds = maskNet.predict(faces, batch_size=32)

#     return (locs, preds)

# # ---------------- LOAD MODELS ----------------
# prototxtPath = r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\deploy.prototxt"
# weightsPath = r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\res10_300x300_ssd_iter_140000.caffemodel"
# faceNet = cv2.dnn.readNet(prototxtPath, weightsPath)

# maskNet = load_model(r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\mask_detector.h5")

# # ---------------- LOAD IMAGE ----------------
# image_path = r"C:\Users\Administrator\Pictures\Camera Roll\WIN_20241209_19_14_42_Pro.jpg"
# image = cv2.imread(image_path)

# if image is None:
#     raise ValueError(f"Image not found at path: {image_path}")

# # ---------------- DETECTION ----------------
# (locs, preds) = detect_and_predict_mask(image, faceNet, maskNet)

# # ---------------- DRAW RESULTS ----------------
# for (box, pred) in zip(locs, preds):
#     (startX, startY, endX, endY) = box
#     (mask, withoutMask) = pred

#     label = "Mask" if mask > withoutMask else "No Mask"
#     color = (0, 255, 0) if label == "Mask" else (0, 0, 255)
#     label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

#     cv2.putText(image, label, (startX, startY - 10),
#                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)
#     cv2.rectangle(image, (startX, startY), (endX, endY), color, 2)

# # ---------------- DISPLAY BIGGER IMAGE ----------------
# cv2.namedWindow("Mask Detection", cv2.WINDOW_NORMAL)   # make window resizable
# cv2.resizeWindow("Mask Detection", 700, 500)          # set bigger window size

# # Optional: scale image proportionally (uncomment if needed)
# # scale_percent = 150
# # width = int(image.shape[1] * scale_percent / 100)
# # height = int(image.shape[0] * scale_percent / 100)
# # dim = (width, height)
# # image = cv2.resize(image, dim, interpolation=cv2.INTER_LINEAR)

# cv2.imshow("Mask Detection", image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# below is frontend using tkinter

# %%
# Face Mask Detection GUI using Tkinter
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import cv2
import tkinter as tk
from tkinter import filedialog, messagebox


def resize_to_fit(frame, max_width=900, max_height=700):
    h, w = frame.shape[:2]
    scale = min(max_width / w, max_height / h)

    if scale < 1:  # Resize only if too large
        new_w = int(w * scale)
        new_h = int(h * scale)
        frame = cv2.resize(frame, (new_w, new_h))
        
    return frame


def detect_and_predict_mask(frame, faceNet, maskNet):
    (h, w) = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300),
                                 (104.0, 177.0, 123.0))
    faceNet.setInput(blob)
    detections = faceNet.forward()

    faces, locs, preds = [], [], []

    for i in range(0, detections.shape[2]):
        confidence = detections[0, 0, i, 2]

        if confidence > 0.5:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            startX, startY = max(0, startX), max(0, startY)
            endX, endY = min(w - 1, endX), min(h - 1, endY)

            face = frame[startY:endY, startX:endX]
            if face.size == 0:
                continue

            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)

            faces.append(face)
            locs.append((startX, startY, endX, endY))

    if len(faces) > 0:
        preds = maskNet.predict(np.array(faces, dtype="float32"))

    return locs, preds


# Load Models
faceNet = cv2.dnn.readNet(
    r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\deploy.prototxt",
    r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\res10_300x300_ssd_iter_140000.caffemodel"
)

maskNet = load_model(
    r"C:\Users\Administrator\Desktop\krish_P_Detection_system\YOLO_perfect\mask_detector.h5"
)


def draw_results(frame, locs, preds):
    for (box, pred) in zip(locs, preds):
        (mask, withoutMask) = pred
        (startX, startY, endX, endY) = box

        label = "Mask" if mask > withoutMask else "No Mask"
        color = (0, 255, 0) if label == "Mask" else (0, 0, 255)
        label = f"{label}: {max(mask, withoutMask) * 100:.2f}%"

        cv2.putText(frame, label, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.75, color, 2)
        cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

    return frame


# ---------------- GUI Functions ----------------
def upload_image():
    path = filedialog.askopenfilename()
    if not path:
        return

    image = cv2.imread(path)
    locs, preds = detect_and_predict_mask(image, faceNet, maskNet)
    output = draw_results(image, locs, preds)
    output = resize_to_fit(output)

    cv2.imshow("Image Result", output)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


def upload_video():
    path = filedialog.askopenfilename()
    if not path:
        return

    cap = cv2.VideoCapture(path)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        locs, preds = detect_and_predict_mask(frame, faceNet, maskNet)
        frame = draw_results(frame, locs, preds)
        frame = resize_to_fit(frame)

        cv2.imshow("Video Result", frame)

        if cv2.getWindowProperty("Video Result", 0) < 0:
            break
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


def start_webcam():
    cap = cv2.VideoCapture(0)

    while True:
        ret, frame = cap.read()
        locs, preds = detect_and_predict_mask(frame, faceNet, maskNet)
        frame = draw_results(frame, locs, preds)
        frame = resize_to_fit(frame)

        cv2.imshow("Webcam Detection", frame)

        if cv2.getWindowProperty("Webcam Detection", 0) < 0:
            break
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


def safe_exit():
    cv2.destroyAllWindows()
    root.destroy()


# ---------------- GUI Layout ----------------
root = tk.Tk()
root.title("Face Mask Detection System")
root.geometry("400x400")
root.configure(bg="skyblue")

tk.Label(root, text="Face Mask Detection System",
         font=("Arial", 18, "bold"), bg="skyblue").pack(pady=20)

tk.Button(root, text="Upload Image", command=upload_image,
          font=("Arial", 14), bg="green", fg="white", width=20).pack(pady=10)

tk.Button(root, text="Upload Video", command=upload_video,
          font=("Arial", 14), bg="blue", fg="white", width=20).pack(pady=10)

tk.Button(root, text="Start Webcam", command=start_webcam,
          font=("Arial", 14), bg="purple", fg="white", width=20).pack(pady=10)

tk.Button(root, text="Exit", command=safe_exit,
          font=("Arial", 14), bg="red", fg="white", width=20).pack(pady=20)

root.mainloop()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
